# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_global = pd.read_csv('global_temperature.csv', names = ['ano','grau celsius'])

# %%
df_global
# Out:
#       ano     grau celsius
# 0    year  degrees_celsius
# 1    1850             7.74
# 2    1851             8.09
# 3    1852             7.97
# 4    1853             7.93
# ..    ...              ...
# 163  2012              9.5
# 164  2013              9.6
# 165  2014             9.56
# 166  2015             9.82
# 167  2016            10.02
#
# [168 rows x 2 columns]

# %%
type(df_global)
# Out:
# pandas.core.frame.DataFrame

# %%
df_global.isnull()
# Out:
#        ano  grau celsius
# 0    False         False
# 1    False         False
# 2    False         False
# 3    False         False
# 4    False         False
# ..     ...           ...
# 163  False         False
# 164  False         False
# 165  False         False
# 166  False         False
# 167  False         False
#
# [168 rows x 2 columns]

# %%
df_global.isnull().sum()
# Out:
# ano             0
# grau celsius    0
# dtype: int64

# %%
df_global_iloc = df_global.iloc[1:]

# %% [markdown]
# or

# %%
df_global.drop(df_global.head(1).index, inplace=True)

# %%
df_global
# Out:
#       ano grau celsius
# 1    1850         7.74
# 2    1851         8.09
# 3    1852         7.97
# 4    1853         7.93
# 5    1854         8.19
# ..    ...          ...
# 163  2012          9.5
# 164  2013          9.6
# 165  2014         9.56
# 166  2015         9.82
# 167  2016        10.02
#
# [167 rows x 2 columns]

# %%
df_global_index = df_global.reset_index()

# %%
df_global_index
# Out:
#      index   ano grau celsius
# 0        1  1850         7.74
# 1        2  1851         8.09
# 2        3  1852         7.97
# 3        4  1853         7.93
# 4        5  1854         8.19
# ..     ...   ...          ...
# 162    163  2012          9.5
# 163    164  2013          9.6
# 164    165  2014         9.56
# 165    166  2015         9.82
# 166    167  2016        10.02
#
# [167 rows x 3 columns]

# %%
countries = {'Africa':'Ghana','Europe':'France','Europe':'Greece','Asia':'Vietnam','Europe':'Lithuania'}

# %%
df_global_index["continent"] = np.random.choice(list(countries), len(df_global_index))

# %%
df_global_index
# Out:
#      index   ano grau celsius color continent
# 0        1  1850         7.74     i      Asia
# 1        2  1851         8.09     i      Asia
# 2        3  1852         7.97     i    Europe
# 3        4  1853         7.93     i      Asia
# 4        5  1854         8.19     i      Asia
# ..     ...   ...          ...   ...       ...
# 162    163  2012          9.5     i    Africa
# 163    164  2013          9.6     i    Europe
# 164    165  2014         9.56     i    Africa
# 165    166  2015         9.82     i    Europe
# 166    167  2016        10.02     i    Europe
#
# [167 rows x 5 columns]

# %%
# How to fill pandas dataframe columns with random dictionary values
# https://stackoverflow.com/questions/47464362/how-to-fill-pandas-dataframe-columns-with-random-dictionary-values

# %%
df_global_index.drop(['index','color'], axis=1, inplace=True)

# %%
df_global_index
# Out:
#       ano grau celsius continent
# 0    1850         7.74      Asia
# 1    1851         8.09      Asia
# 2    1852         7.97    Europe
# 3    1853         7.93      Asia
# 4    1854         8.19      Asia
# ..    ...          ...       ...
# 162  2012          9.5    Africa
# 163  2013          9.6    Europe
# 164  2014         9.56    Africa
# 165  2015         9.82    Europe
# 166  2016        10.02    Europe
#
# [167 rows x 3 columns]

# %%
plt.figure(figsize = (20, 14))

sns.set(style='white')
plt.plot(df_global_index['ano'], df_global_index['grau celsius'])

#seaborn.lineplot(*, x=None, y=None, hue=None, size=None,
                 #style=None, data=None, palette=None, hue_order=None, 
                 #hue_norm=None, sizes=None, size_order=None, size_norm=None, 
                 #dashes=True, markers=None, style_order=None, units=None, estimator='mean', 
                # ci=95, n_boot=1000, seed=None, sort=True, err_style='band', err_kws=None, 
                # legend='auto', ax=None, label =''**kwargs)
########################

#plt.ylim(20,1)
#plt.xlim(3500,1000)


#plt.xticks(np.arange(1000,3500,500))
#plt.yticks(np.arange(0,20,5))

##########################

plt.title("California Rooms vs Bedrooms")
plt.xlabel("Total rooms")
plt.ylabel("Total bedrooms")
plt.legend(title='legenda')

#plt.savefig("fssssss.svg", format='svg', dpi=1200)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
def main():
    args = parse_args()
    X, labels = np.loadtxt(args.embeddings_path), np.loadtxt(args.labels_path, dtype=np.str)
    tsne = TSNE(n_components=2, n_iter=10000, perplexity=5, init='pca', learning_rate=200, verbose=1)
    transformed = tsne.fit_transform(X)

    y = set(labels)
    labels = np.array(labels)
    plt.figure(figsize=(20, 14))
    colors = cm.rainbow(np.linspace(0, 1, len(y)))
    for label, color in zip(y, colors):
        points = transformed[labels == label, :]
        plt.scatter(points[:, 0], points[:, 1], c=[color], label=label, s=200, alpha=0.5)
        for p1, p2 in random.sample(list(zip(points[:, 0], points[:, 1])), k=min(1, len(points))):
            plt.annotate(label, (p1, p2), fontsize=30)

    plt.savefig('tsne_visualization.png', transparent=True, bbox_inches='tight', pad_inches=0)
    plt.show()

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-57-1ac45537c0a3> in main()
#       1 def main():
# ----> 2     args = parse_args()
#       3     X, labels = np.loadtxt(args.embeddings_path), np.loadtxt(args.labels_path, dtype=np.str)
#       4     tsne = TSNE(n_components=2, n_iter=10000, perplexity=5, init='pca', learning_rate=200, verbose=1)
#       5     transformed = tsne.fit_transform(X)
#
# NameError: name 'parse_args' is not defined

# %%
countries = {'Africa':'Ghana','Europe':'France','Europe':'Greece','Asia':'Vietnam','Europe':'Lithuania'}
